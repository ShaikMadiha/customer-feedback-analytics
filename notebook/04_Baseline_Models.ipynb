# %%
# ==========================================
# PHASE 4 : MACHINE LEARNING MODELS
# ==========================================

import pandas as pd
import numpy as np

import joblib

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression

from sklearn.svm import LinearSVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/preprocessed_reviews.csv")

df.head()
# Out:
#                                                 Text Sentiment  \
# 0  I have bought several of the Vitality canned d...  Positive
# 1  Product arrived labeled as Jumbo Salted Peanut...  Negative
# 2  This is a confection that has been around a fe...  Positive
# 3  If you are looking for the secret ingredient i...  Negative
# 4  Great taffy at a great price.  There was a wid...  Positive
#
#                                           Clean_Text  \
# 0  bought several vitality canned dog food produc...
# 1  product arrived labeled jumbo salted peanutsth...
# 2  confection around century light pillowy citrus...
# 3  looking secret ingredient robitussin believe f...
# 4  great taffy great price wide assortment yummy ...
#
#                                            BERT_Text  Label
# 0  I have bought several of the Vitality canned d...      2
# 1  Product arrived labeled as Jumbo Salted Peanut...      0
# 2  This is a confection that has been around a fe...      2
# 3  If you are looking for the secret ingredient i...      0
# 4  Great taffy at a great price. There was a wide...      2

# %%
X = df["Clean_Text"]

y = df["Label"]

# %%
df = df.dropna(subset=["Clean_Text"])

# %%
vectorizer = TfidfVectorizer(
    max_features=20000,
    ngram_range=(1, 2),
    min_df=5,
    max_df=0.90,
    sublinear_tf=True
)

X = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.2,

    stratify=y,

    random_state=42

)

# %%
lr = LogisticRegression(
    C=3,
    class_weight="balanced",
    max_iter=5000,
    random_state=42
)

lr.fit(X_train, y_train)

lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=3, class_weight='balanced', max_iter=5000, random_state=42)

# %%
lr_pred = lr.predict(X_test)

# %%
accuracy = accuracy_score(y_test, lr_pred)

print(f"Accuracy : {accuracy:.4f}")
# Out:
# Accuracy : 0.8313

# %%
print(

classification_report(

y_test,

lr_pred,

target_names=["Negative","Neutral","Positive"]

)

)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.69      0.79      0.74     16407
#      Neutral       0.34      0.67      0.45      8528
#     Positive       0.97      0.85      0.91     88756
#
#     accuracy                           0.83    113691
#    macro avg       0.67      0.77      0.70    113691
# weighted avg       0.88      0.83      0.85    113691

# %%
cm = confusion_matrix(y_test, lr_pred)

disp = ConfusionMatrixDisplay(

    confusion_matrix=cm,

    display_labels=["Negative","Neutral","Positive"]

)

disp.plot(cmap="Blues")

plt.show()

# %%
svm = LinearSVC(
    C=0.5,
    class_weight="balanced",
    max_iter=5000,
    random_state=42
)
svm.fit(

    X_train,

    y_train

)
# Out:
# LinearSVC(C=1.5, class_weight='balanced', max_iter=5000, random_state=42)

# %%
svm_pred = svm.predict(X_test)

# %%
print(

"Accuracy:",

accuracy_score(

y_test,

svm_pred

)

)
# Out:
# Accuracy: 0.877457318521255

# %%
print(

classification_report(

y_test,

svm_pred,

target_names=["Negative","Neutral","Positive"]

)

)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.74      0.79      0.77     16407
#      Neutral       0.45      0.53      0.49      8528
#     Positive       0.95      0.93      0.94     88756
#
#     accuracy                           0.88    113691
#    macro avg       0.72      0.75      0.73    113691
# weighted avg       0.89      0.88      0.88    113691

# %%
comparison = pd.DataFrame({

    "Model":[

        "Logistic Regression",

        "Linear SVM"

    ],

    "Accuracy":[

        accuracy_score(y_test,lr_pred),

        accuracy_score(y_test,svm_pred)

    ]

})

comparison
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.831315
# 1           Linear SVM  0.877457

# %%
joblib.dump(svm, "../models/linear_svm.pkl")
joblib.dump(vectorizer, "../models/tfidf_vectorizer.pkl")
joblib.dump(lr, "../models/logistic_regression.pkl")
# Out:
# ['../models/logistic_regression.pkl']

# %%
# Out:
# LinearSVC(C=0.5, class_weight='balanced', max_iter=5000, random_state=42)
